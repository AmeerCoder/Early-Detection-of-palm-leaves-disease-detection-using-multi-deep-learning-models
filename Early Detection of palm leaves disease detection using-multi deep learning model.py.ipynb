# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 #!unzip bact_50.zip
#!unzip heal_50.zip
import tensorflow as tf
from PIL import Image
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import datetime

# %%
from PIL import Image
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
import numpy as np
import os
import datetime
import keras
from tensorflow import keras
import keras.layers as layers
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
# from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
# from keras.layers.advanced_activations import LeakyReLU
import tensorflow as tf

# %%
#number of images , px , py , rgb
start = datetime.datetime.now()
x = [] # images
y = [] # categories

folder_disease = '/content/drive/MyDrive/datasets/brown spots'
folder_healthy = '/content/drive/MyDrive/datasets/healthy'
name_encode = {'/content/drive/MyDrive/datasets/brown spots':1 , '/content/drive/MyDrive/datasets/healthy':0}

def image_to_array(folder , name):
   for image in os.listdir(folder):
     loaded_image = Image.open(os.path.join(folder , image))
     resize_image = Image.Image.resize(loaded_image , [224,224])
    #  gyra = cv2.cvtColor(np.float32(resize_image), cv2.COLOR_RGB2GRAY)
     image_array = np.array(resize_image)
     x.append(image_array)
     y.append(name_encode[name])

def images_show(index):
   plt.imshow(x[index])
   plt.show()
   print(y[index])



image_to_array(folder_healthy , '/content/drive/MyDrive/datasets/healthy')
image_to_array(folder_disease , '/content/drive/MyDrive/datasets/brown spots')
y = to_categorical(y , num_classes=2)
x = np.array(x)
images_show(500)
# Out:
# [1. 0.]

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout
from keras.layers.normalization.batch_normalization import BatchNormalization

# %%
from keras.layers import Activation,Conv2D,Dense,Flatten,MaxPool2D
from keras.models import Sequential
model = keras.Sequential()

# %%
model.add(Conv2D(input_shape=(224,224,3),filters=64 ,kernel_size=(3,3),padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=64 , kernel_size=(3,3) , padding='same' , ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))

model.add(Conv2D(filters=128 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=128 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))

model.add(Conv2D(filters=256 , kernel_size=(3,3) , padding='same'))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=256 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=256 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=256 , kernel_size=(3,3) , padding='same' ))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same'))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))

#model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same'))
#model.add(BatchNormalization())
#model.add(Activation('relu'))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
#model.add(BatchNormalization())
model.add(Activation('relu'))





model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
model.add(Activation('relu'))
model.add(BatchNormalization())

# model.add(Conv2D(filters=512 , kernel_size=(3,3) , padding='same' ))
# model.add(Activation('relu'))
# model.add(BatchNormalization())

model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))



model.add(Flatten())
model.add(Dense(4096))
model.add(Dropout(0.3))
# model.add(layers.Dropout(0.5))
#model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Dropout(0.2))


model.add(Dense(4096))
model.add(Dropout(0.3))
#model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Dropout(0.2))
model.add(BatchNormalization())

#model.add(Dense(512))
#model.add(Activation('relu'))
#model.add(Dropout(0.2))
#model.add(BatchNormalization())

model.add(Dense(2))
#model.add(BatchNormalization())
model.add(Activation('sigmoid'))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-0f581600ebb2> in <cell line: 20>()
#      18 model.add(Activation('relu'))
#      19
# ---> 20 model.add(MaxPool2D(pool_size=(2,2) , strides=(2,2)))
#      21
#      22 model.add(Conv2D(filters=256 , kernel_size=(3,3) , padding='same'))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30 , random_state = 42)
from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.optimizers import SGD

optimizers = Adam(learning_rate=0.001)

model.compile(optimizer=optimizers, loss='binary_crossentropy',metrics=['acc'])

#h= model.fit(
 #   aug.flow(x_train, y_train, batch_size=32),
  #  validation_data=(x_test, y_test),
   # epochs=50, verbose=1
    #)


h = model.fit(x_train,y_train,batch_size=32, epochs=50,verbose=1, validation_data=(x_test,y_test))


model.save('proposed_model.hdf5')

_, acc = model.evaluate(x_test, y_test)
print("Accuracy = ", (acc * 100.0), "%")

loss = h.history['loss']
val_loss = h.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs ,loss, 'y' , label = 'Training loss')
plt.plot(epochs , val_loss , 'r' , label = 'validation_loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

accuracy = h.history['acc']
val_accuracy = h.history['val_acc']
epochs = range(1, len(loss) + 1)
plt.plot(epochs ,accuracy, 'y' , label = 'Training acc')
plt.plot(epochs , val_accuracy , 'r' , label = 'validation_acc')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()

#plt.plot(h.history['acc'], label = 'Train')
#plt.plot(h.history['val_acc'] , label = 'Test')
#plt.plot(h.history['loss'], label = 'acc loss')
#plt.plot(h.history['val_loss'], label = 'val loss')
#plt.title('Alexnet')
#plt.xlabel('Epoch Number')
#plt.ylabel('Accuracy')
#plt.legend(loc='lower right')
#plt.show()

stop  = datetime.datetime.now()
print("Total execution time is: ", stop-start)

# Predicting the Test set results
#y_pred = model.predict(x_test)
#y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
#import seaborn as sns
#from sklearn.metrics import confusion_matrix
#cm = confusion_matrix(y_test, y_pred)
#sns.heatmap(cm, annot=True)
# Out:
# Epoch 1/50
# 308/308 [==============================] - 230s 647ms/step - loss: 0.2826 - acc: 0.9164 - val_loss: 0.8678 - val_acc: 0.7488
# Epoch 2/50
# 308/308 [==============================] - 175s 568ms/step - loss: 0.1265 - acc: 0.9583 - val_loss: 2.9091 - val_acc: 0.6330
# Epoch 3/50
# 308/308 [==============================] - 174s 567ms/step - loss: 0.0966 - acc: 0.9688 - val_loss: 0.1103 - val_acc: 0.9587
# Epoch 4/50
# 308/308 [==============================] - 174s 564ms/step - loss: 0.0813 - acc: 0.9728 - val_loss: 1.9872 - val_acc: 0.6636
# Epoch 5/50
# 308/308 [==============================] - 174s 565ms/step - loss: 0.0700 - acc: 0.9763 - val_loss: 0.9913 - val_acc: 0.8377
# Epoch 6/50
# 308/308 [==============================] - 174s 566ms/step - loss: 0.0633 - acc: 0.9785 - val_loss: 0.6810 - val_acc: 0.8453
# Epoch 7/50
# 308/308 [==============================] - 174s 565ms/step - loss: 0.0475 - acc: 0.9859 - val_loss: 3.6711 - val_acc: 0.9146
# Epoch 8/50
# ...

# %%
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2%' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
y_pred=model.predict(x_test)
# Compute confusion matrix
cnf_matrix = confusion_matrix(np.argmax(y_test,axis=1), np.argmax(y_pred,axis=1))
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=['Healthy', 'Brown spots'],normalize=True,
                      title='Confusion Matrix')
plt.show()
# Out:
# 132/132 [==============================] - 20s 145ms/step
# Normalized confusion matrix

# %%
from sklearn.metrics import classification_report
labels = ['Healthy', 'Brown spots']

classificationReport = classification_report(np.argmax(y_test,axis=1), np.argmax(y_pred,axis=1), target_names=labels)
print(classificationReport)
#plot_classification_report(classificationReport)
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.99      1.00      1.00       365
#  Brown spots       1.00      1.00      1.00      3850
#
#     accuracy                           1.00      4215
#    macro avg       1.00      1.00      1.00      4215
# weighted avg       1.00      1.00      1.00      4215

# %%
# Compute ROC curve and ROC area for each class
plt.rcParams["figure.figsize"] = (8,6)

from sklearn.metrics import roc_curve, auc

fpr = dict()
tpr = dict()
roc_auc = dict()
y_test1 = np.argmax(y_test,axis=1)
y_pred1 = np.argmax(y_pred,axis=1)

fpr, tpr, _ = roc_curve(y_test1, y_pred1)
roc_auc = auc(fpr, tpr)


plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
import numpy as np

def mse(y_test, y_pred):
    actual, pred = np.array(y_test), np.array(y_pred)
    return np.square(np.subtract(y_test,y_pred)).mean()

# %%
# ✅ correct imports
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image

import cv2 as cv
from keras.utils import load_img, img_to_array
import tensorflow as tf
from tensorflow.keras.utils import load_img
from keras.backend import resize_images
from keras.preprocessing import image

img = tf.keras.utils.load_img("/content/drive/MyDrive/datasets/brown spots/brownspots-100.jpg",target_size=(224,224))



# img = load_img("/content/drive/MyDrive/Tooth1 Caries and Non Caries Final DATASET - Copy/Tooth caries and non caries dataset/NON CARIES/nc (10).jpg",target_size=(150,150)")

# img = image.load_img("/content/drive/MyDrive/Tooth1 Caries and Non Caries Final DATASET - Copy/Tooth caries and non caries dataset/NON CARIES/nc (10).jpg",target_size=(150,150))


resize_image = Image.Image.resize(img , [224,224])

# gray = cv2.cvtColor(np.float32(img), cv2.COLOR_RGB2GRAY)
img = np.asarray(resize_image)


# img = cv.imread(resize_images)

# plt.imshow(np.real(img))
# plt.show()

# plt.imshow(img)


# Convert to numpy array
# img = np.array(img)

# Convert data type to float32
# img = img.astype('float32')

# Normalize the data (optional)
# img /= 255.0


# plt.imshow(img)

plt.imshow(img)


img = np.expand_dims(img, axis=0)
from keras.models import load_model
saved_model = load_model("/content/drive/MyDrive/proposed_model.h5")
output = saved_model.predict(img)
if output[0][0] > output[0][1]:
    print("Healthy")
else:
    print('Brown spots')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x78bd763984c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 386ms/step
# Brown spots

# %%
y_train[0]

# %%
score = model.evaluate(x_test, y_test)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
